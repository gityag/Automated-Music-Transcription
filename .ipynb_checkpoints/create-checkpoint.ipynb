# %%
# !pip install mido
import numpy as np
from mido import Message, MidiTrack, MidiFile
import time
import os
from collections import defaultdict
from collections import namedtuple
import pickle
import random
random.seed(123)
import ntpath
import librosa
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 5, in <module>
#     from pip._internal.cli.main import main
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 10, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/build_env.py", line 19, in <module>
#     from pip._internal.cli.spinners import open_spinner
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/spinners.py", line 9, in <module>
#     from pip._internal.utils.logging import get_indentation
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/logging.py", line 13, in <module>
#     from pip._vendor.rich.console import (
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/__init__.py", line 17, in <module>
#     _IMPORT_CWD = os.path.abspath(os.getcwd())
# OSError: [Errno 107] Transport endpoint is not connected

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/kaggle
# Out:
# /content/gdrive/MyDrive/kaggle

# %%
#Constant-Q transfrom
def audio_segments_cqt(audio_segment_time_series, sr):
    cqt_of_segment = librosa.cqt(audio_segment_time_series, sr=sr)
    # Remove the imaginary number part of the CQT (ie We don't care where in the wave we are when we start reading it)
    cqt_of_segment_real = cqt_of_segment.real
    cqt_of_segment_copy_real = np.array(cqt_of_segment_real, dtype='float32')
    return cqt_of_segment_copy_real

# %%
#Encode MIDI segments
def encode_midi_segment(midi_start_time, midi_segment, midi_segment_length, lowest, highest):
    lowest = 21 #value for the entire SMD dataset
    highest = 107 #value for the entire SMD dataset
    num_notes = highest - lowest + 1
    num_discrete_time_values = 6
    # instantiate shape
    encoded_segment = np.zeros(shape=(num_notes, num_discrete_time_values))
    midi_segment_bin_time = []
    times_aligned_to_closest_bucket_divide = []
    bucket_length = midi_segment_length / num_discrete_time_values
    bucket_divides = np.arange(0, midi_segment_length, bucket_length)

    for message in midi_segment:
        time = message[-1]
        time_scaled = time - midi_start_time
        time_aligned_to_closest_bucket_divide = min(bucket_divides, key=lambda x:abs(x-time_scaled))
        # add the time to the list of message times we'll have to handle
        times_aligned_to_closest_bucket_divide.append(time_aligned_to_closest_bucket_divide)

    # create a list of bin integers (corresponding to each message in the segment)
    bins = []
    for time in times_aligned_to_closest_bucket_divide:
        nth_bucket = 0
        for bucket in bucket_divides:
            if time == bucket:
                bins.append(nth_bucket)
            nth_bucket += 1

    # build midi messages list with bin integers as time value
    i = 0
    for message in midi_segment:
        on_or_off = message[0]
        pitch = message[1]
        pitch_scaled = pitch - lowest
        bin = bins[i]
        midi_segment_bin_time.append([on_or_off, pitch_scaled, bin])
        i += 1

    for message in midi_segment_bin_time:
        on_or_off = message[0]
        pitch_scaled = message[1]
        bin = message[-1]
        if on_or_off == 'note_on':
            encoded_segment[pitch_scaled, bin:] = 1 # turn note on for the rest of the segment
        else:  # if note off
            if encoded_segment[pitch_scaled, bin - 1] == 1: # if note was not turned on inside this bin
                encoded_segment[pitch_scaled, bin:] = 0

    return encoded_segment, num_discrete_time_values, num_notes

# %%
#Decode MIDI

def decode_midi_segment(encoded_segment, midi_segment_length, num_discrete_time_values, lowest):
    lowest = 21  # value for the entire SMD dataset
    decoded_midi_segment = []

    notes_on, times_on = np.where(encoded_segment == 1) #tuple of arrays of x and y indices where a given condition holds in an array.3.0
    bucket_length = midi_segment_length / num_discrete_time_values
    bucket_start_times = np.arange(0, midi_segment_length, bucket_length)
    for i in range(len(notes_on)):
        pitch_scaled = notes_on[i]
        column = times_on[i]
        pitch = pitch_scaled + lowest
        previous_pitch_scaled = notes_on[i-1]
        if pitch_scaled != previous_pitch_scaled:
            note_on_time = bucket_start_times[column]
            midi_message = ['note_on', pitch, note_on_time]
            decoded_midi_segment.append(midi_message)
        last_column = num_discrete_time_values - 1
        if column != last_column:
            #if not last note in notes on
            if pitch_scaled != notes_on[-1]:
                next_pitch_scaled = notes_on[i+1]
                if pitch_scaled != next_pitch_scaled:
                    note_off_time = bucket_start_times[column + 1]
                    midi_message = ['note_off', pitch, note_off_time]
                    decoded_midi_segment.append(midi_message)
        if column == last_column:
            note_off_time = bucket_start_times[0] + midi_segment_length
            midi_message = ['note_off', pitch, note_off_time]
            decoded_midi_segment.append(midi_message)
    decoded_midi_segment_chronological = sorted(decoded_midi_segment, key=lambda x: float(x[-1]))
    return decoded_midi_segment_chronological

















    # scaled_notes_on = []
    # len_discrete_time_column_in_seconds = midi_segment_length / num_discrete_time_values
    # for i in range(num_discrete_time_values): #for each column
    #     column = encoded_segment[:,i]
    #     column_start_time = i * len_discrete_time_column_in_seconds
    #     scaled_note_num = 0
    #     midi_message = []
    #
    #     for scaled_note in scaled_notes_on:
    #         if column[scaled_note] == 0:
    #             midi_message.append('note_off')
    #             pitch = scaled_note_num + lowest
    #             midi_message.append(pitch)
    #             midi_message.append(column_start_time)
    #             scaled_notes_on.remove(scaled_note)
    #
    #     for binary_note in column: #just one column
    #         if binary_note == 1 and scaled_note_num not in scaled_notes_on:
    #             midi_message.append('note_on')
    #             pitch = scaled_note_num + lowest
    #             midi_message.append(pitch)
    #             midi_message.append(column_start_time)
    #             scaled_notes_on.append(scaled_note_num)
    #         scaled_note_num += 1
    #
    #     if len(midi_message) > 0:
    #         decoded_midi_segment.append(midi_message)
    #return decoded_midi_segment_bin_time

# %%
AudioDecoded = namedtuple('AudioDecoded', ['time_series', 'sr'])

def find_audio_files(directory_str):
    directory_str_audio = directory_str + "/audio"
    audio_files = librosa.util.find_files(directory_str_audio, recurse=False, case_sensitive=True) #recurse False
    # means subfolders are not searched; case_sensitive True ultimately keeps songs from being
    # listed twice
    return audio_files

def load_audio(audio_file):
    time_series, sr = librosa.core.load(audio_file, sr=22050*4)
    time_series_and_sr = AudioDecoded(time_series, sr)
    return time_series_and_sr

# %%
def audio_timestamps(audio_file, time_series_and_sr):
    sr = time_series_and_sr[1]

    duration_song = librosa.core.get_duration(y=time_series_and_sr[0], sr=sr)
    audio_segment_length = 1
    midi_segment_length = 0.5
    padding = midi_segment_length / 2
    audio_start_times_missing_first = np.arange(
        padding,(duration_song-midi_segment_length), midi_segment_length)
            # For ex,
            # this will mean that for a song of len 157 seconds, the last needed MIDI file would be 156.5-157,
            # so the last audio start time should be 156.25. In this example
            # duration_song minus midi_segment_length is 156.5
    audio_start_times = np.concatenate((np.asarray([0]), audio_start_times_missing_first),
                                       axis=0)
    return audio_start_times, audio_segment_length, midi_segment_length

# %%
def silent_audio(sr, padding):
    zeros = int(sr * padding)
    audio = np.zeros((zeros))
    maxv = np.iinfo(np.int16).max #numpy.iinfo(type): Machine limits for integer types.
    silent_audio_time_series = (audio * maxv).astype(np.int16)
    return silent_audio_time_series

# %%
# padding_portion provides the option to set padding to zero, so that if a better temporally aligned dataset is used
# in the future, the code can segmented without padding
def load_segment_of_audio_and_save(audio_file, start, audio_segment_length, midi_segment_length, duration_song, sr,
                                   padding_portion=.5):
    padding = midi_segment_length * padding_portion
    # If you don't want to pad the audio segments, comment out the following code and move the
    # line inside the else condition out of the else condition
    if start == 0:
        segment_duration = (audio_segment_length - padding)
        audio_segment_time_series_og, sr = librosa.core.load(audio_file, offset=0,
                                                          duration=segment_duration, sr=sr)
        silence = silent_audio(sr, padding)
        audio_segment_time_series = np.concatenate((silence, audio_segment_time_series_og), axis=0)
    elif (duration_song - start) < audio_segment_length: #if we're at the end of a song and need
        # padding
        segment_duration = (duration_song - start)
        audio_segment_time_series_og, sr = librosa.core.load(audio_file, offset=start,
                                                          duration=segment_duration, sr=sr)
        audio_segment_time_series = np.concatenate(
            (audio_segment_time_series_og, silent_audio(sr, (audio_segment_length-segment_duration))),axis=0)
    else:
        audio_segment_time_series, sr = librosa.core.load(audio_file, offset=start,
                                                          duration=audio_segment_length, sr=sr)
    filename_format = "./audio_and_midi/segments/audio/{0}_start_time_{1}.wav"
    filename = filename_format.format(ntpath.basename(audio_file)[:-4], str(start))
    # for testing by listening to audio (currently written for windows)
    # librosa.output.write_wav(filename, audio_segment_time_series, sr)

    return audio_segment_time_series

# %%
def load_midi(directory_str, audio_file):
    midi_base_str = directory_str + "/midi/"
    midi_str = midi_base_str + ntpath.basename(audio_file)[:-4] + ".mid"
    midi_file = MidiFile(midi_str)
    return midi_file

def create_simplified_midi(midi_file):
    simplified_midi = []
    ticks_since_start = 0

    # debugging/for future use with a dataset other than Saarland Music Dataset:
    # check for note offs without note ons and check control changes in song
    print("midi file:", midi_file)
    count_ons = 0
    count_offs = 0
    control_changes = []

    for message in midi_file.tracks[0]:
        if message.type == "set_tempo":
            tempo_in_microsecs_per_beat = message.tempo
    for message in midi_file.tracks[-1]:
        # convert delta time (delta ticks) to TICKS since start
        ticks_since_start += message.time
        if message.type == "note_on" or message.type == "note_off":
            simplified_midi.append([message.type, message.note, ticks_since_start])

            # debugging/for future use with a dataset other than SMD
            if message.type == "note_on":
                count_ons += 1
            else:
                count_offs += 1

        # debugging/for future use with a dataset other than SMD: check control changes in song; check for 123
        if message.type == 'control_change':
            control_changes.append(message.control)
            if message.control == 123:
                print("CONTROL ALL NOTES OFF MESSAGE!")

    # debugging/for future use with a dataset other than SMD
    if count_ons != count_offs:
        print("INEQUAL NUM ONS AND OFFS (prior to simplified midi)")
        print("count ons:", count_ons)
        print("offs:", count_offs)

    # convert ticks since start to absolute seconds
    tempo_in_secs_per_beat = tempo_in_microsecs_per_beat / 1000000
    ticks_per_beat = midi_file.ticks_per_beat
    secs_per_tick = tempo_in_secs_per_beat / ticks_per_beat
    length_in_secs_full_song = ticks_since_start * secs_per_tick
    for message in simplified_midi:
        message[-1] = message[-1] / ticks_since_start * length_in_secs_full_song

    # For comparison
    midi_length = midi_file.length
    # print("midi_file.length:", midi_file.length)
    # print("length based on last note off:", length_in_secs_full_song)

    # debugging/for future use with a dataset other than SMD
    #print(set(control_changes))

    return simplified_midi, ticks_since_start, length_in_secs_full_song

# %%
def chop_simplified_midi(midi_file, midi_segment_length, simplified_midi, absolute_ticks_last_note, midi_start_times):

    # debugging/for future use with a dataset other than SMD: check for note ons and offs equal
    count_note_on = 0
    count_note_off = 0
    for message in simplified_midi:
        message_type = message[0]
        if message_type == 'note_on':
            count_note_on += 1
        if message_type == 'note_off':
            count_note_off += 1
    if count_note_on != count_note_off:
        print("midi file:", midi_file)
        print("inequal num ons and offs")

    # erase a redundant note_on or a redundant note off of the same pitch
    pitches_on = []
    messages_to_erase = []
    for message in simplified_midi:
        message_type = message[0]
        pitch = message[1]
        if message_type == 'note_on':
            if pitch in pitches_on:
                messages_to_erase.append(message)
            else:
                pitches_on.append(pitch)
        elif message_type == 'note_off':
            if pitch in pitches_on:
                pitches_on.remove(pitch)
            else:
                print("redundant off message found")
                messages_to_erase.append(message)
    for message in messages_to_erase:
        simplified_midi.remove(message)

    time_so_far = 0
    midi_segments =[]
    for midi_start_time in midi_start_times:
        midi_segment = []
        end_time = 0
        for message in simplified_midi:
            end_time = time_so_far + midi_segment_length
            if message[-1] >= time_so_far and message[-1] < end_time:
                midi_segment.append(message)
        midi_segments.append([midi_start_time, midi_segment])
        time_so_far = end_time
    return midi_segments, absolute_ticks_last_note

# %%
def add_note_onsets_to_beginning_when_needed(midi_segments, midi_segment_length):
    # account for notes which start before a segment and end after a segment. For ex, a note which is
    # from .25 to 1.25. Without this special case accounting, this note would not be
    # present in the simplified MIDI clip
    pitches_to_set_to_on_at_beginning_of_segment = []
    for start_time_and_messages in midi_segments:
        start_time = start_time_and_messages[0]
        messages = start_time_and_messages[1]
        for pitch in pitches_to_set_to_on_at_beginning_of_segment:
            messages.insert(0, ["note_on", pitch, start_time])
        pitches_to_set_to_on_at_beginning_of_segment = []
        # goal is to build a dict of dicts like so: {pitch: {num_ons: 4, num_offs: 3}}
        pitch_on_and_off_counts = defaultdict(lambda: defaultdict(int))

        for message in messages:
            pitch = message[1]
            message_type = message[0]
            pitch_on_and_off_counts[pitch][message_type] += 1

        for pitch, on_off_counts_dict in pitch_on_and_off_counts.items():
            count_on = on_off_counts_dict["note_on"]
            count_off = on_off_counts_dict["note_off"]
            if count_on > count_off:
                # this includes the "exclusive ending" (ie This will insert an end time of
                # .5, when technically it should be just under .5)
                pitches_to_set_to_on_at_beginning_of_segment.append(pitch)
                end_time = start_time + midi_segment_length
                messages.append(["note_off", pitch, end_time])
    return midi_segments

# %%
def find_lowest_and_highest_midi_note_numbers(simplified_midi):
    lowest_note_number_so_far = 127
    highest_note_number_so_far = 0
    for message in simplified_midi:
        note_number = message[1]
        if note_number < lowest_note_number_so_far:
            lowest_note_number_so_far = note_number
        if note_number > highest_note_number_so_far:
            highest_note_number_so_far = note_number
    return lowest_note_number_so_far, highest_note_number_so_far

# %%
def reconstruct_midi(midi_filename, midi_segments, absolute_ticks_last_note, length_in_secs_full_song):
    time_so_far = 0
    for midi_segment in midi_segments:

        # time in seconds to absolute ticks
        absolute_ticks_midi_segment = []
        start_time = midi_segment[0]
        messages = midi_segment[1]
        for message in messages:
            note_on_or_off = message[0]
            pitch = message[1]
            scaled_time = message[-1]
            time = scaled_time + start_time
            absolute_ticks = time * absolute_ticks_last_note / length_in_secs_full_song
            absolute_ticks_midi_segment.append([note_on_or_off, pitch, absolute_ticks])
        # time in absolute ticks to delta time
        delta_time_midi_segment = []
        for message in absolute_ticks_midi_segment:
            note_on_or_off = message[0]
            pitch = message[1]
            time = message[-1]
            delta_time = int(time - time_so_far)
            delta_time_midi_segment.append([note_on_or_off, pitch, delta_time])
            time_so_far = time

        mid = MidiFile()
        track = MidiTrack()
        mid.tracks.append(track)
        for message in delta_time_midi_segment:
            note_on_or_off = message[0]
            pitch = int(message[1])
            delta_ticks = message[-1]

            # debugging/for future use with a dataset other than SMD
            if type(delta_ticks) != int or delta_ticks < 0:
                print("time issue")

            track.append(Message(note_on_or_off, note=pitch, time=delta_ticks))

        # for testing by listening to midi (currently written for windows)
        # str_start_time = str(midi_segment[0])
        # filename_format = "C:/Users/Lilly/audio_and_midi/segments/midi/{0}_start_time_{1}.mid"
        # filename = filename_format.format(midi_filename, str_start_time)
        # mid.save(filename)

    return

# %%
def preprocess_audio_and_midi(directory_str):
    audio_files = find_audio_files(directory_str)
    cqt_segments = []
    all_songs_encoded_midi_segments = []
    midi_segments_count = 0
    for audio_file in audio_files:
        audio_decoded = load_audio(audio_file)
        time_series, sr = audio_decoded
        audio_start_times, audio_segment_length, midi_segment_length = audio_timestamps(
            audio_file, audio_decoded)
        midi_file = load_midi(directory_str, audio_file)
         # Load the audio file using librosa.load
        time_series, sr = librosa.load(audio_file, sr=None)

        # Calculate the duration of the audio
        duration_song = librosa.get_duration(y=time_series, sr=sr)
        # duration_song = librosa.core.get_duration(time_series, sr)

        # print time differences
        midi_len = midi_file.length
        if midi_len != duration_song:
            print(audio_file, "audio len - midi len:", duration_song-midi_len)

        simplified_midi, absolute_ticks_last_note, length_in_secs_full_song = create_simplified_midi(
            midi_file)
        lowest_midi_note, highest_midi_note = find_lowest_and_highest_midi_note_numbers(simplified_midi)
        midi_start_times = np.arange(0, length_in_secs_full_song, midi_segment_length)

        if len(audio_start_times) != len(midi_start_times):
            if len(audio_start_times) > len(midi_start_times):
                num_start_times = len(midi_start_times)
                audio_start_times_shortened = audio_start_times[:num_start_times]
                audio_start_times = audio_start_times_shortened
            else:
                num_start_times = len(audio_start_times)
                midi_start_times_shortened = midi_start_times[:num_start_times]
                midi_start_times = midi_start_times_shortened

        for start_time in audio_start_times:
            padding_portion = .5  # padding on each side of audio is midi_segment_length * padding portion
            audio_segment_time_series = load_segment_of_audio_and_save(audio_file, start_time,
                                                                       audio_segment_length,
                                                                       midi_segment_length,
                                                                       duration_song, sr,
                                                                       padding_portion)
            cqt_of_segment = audio_segments_cqt(audio_segment_time_series, sr)
            cqt_segments.append(cqt_of_segment)

        midi_segments, absolute_ticks_last_note = chop_simplified_midi(midi_file, midi_segment_length, simplified_midi, absolute_ticks_last_note, midi_start_times)
        midi_start_times_and_segments_incl_onsets = \
            add_note_onsets_to_beginning_when_needed(midi_segments, midi_segment_length)

        for midi_segment in midi_start_times_and_segments_incl_onsets:
            midi_start_time = midi_segment[0]
            messages = midi_segment[1]
            encoded_segment, num_discrete_time_values, num_notes = encode_midi_segment(midi_start_time, messages, midi_segment_length, lowest_midi_note, highest_midi_note)
            all_songs_encoded_midi_segments.append(encoded_segment)

            # debugging equal num cqt and midi segment
            midi_segments_count += 1

        # # testing
        # # encoded_segment = all_songs_encoded_midi_segments[1]
        # decoded_segments = []
        # for encoded_segment in all_songs_encoded_midi_segments:
        #     decoded_midi = decode_midi_segment(encoded_segment, midi_segment_length, num_discrete_time_values, lowest_midi_note)
        #     decoded_segments.append(decoded_midi)
        # decoded_midi_start_times_and_segments = []
        # for i in range(len(midi_start_times)):
        #     decoded_midi_start_times_and_segments.append([midi_start_times[i], decoded_segments[i]])

        # code for midi reconstruction (for listening purposes)
        # midi_filename = midi_file.filename[35:-4]
        # reconstruct_midi(midi_filename, decoded_midi_start_times_and_segments, absolute_ticks_last_note, length_in_secs_full_song)

    # pickle time
    with open('cqt_segments_midi_segments.pkl', 'wb') as handle:
        pickle.dump(cqt_segments, handle)
        pickle.dump(all_songs_encoded_midi_segments, handle)
    return

# %%
print(os.getcwd())
# Out:
# /content/gdrive/MyDrive/kaggle

# %%
directory_str = "./audio_and_midi"
preprocess_audio_and_midi(directory_str)
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Streaming output truncated to the last 5000 lines.
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=60),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=30),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=30),
#     Message('note_on', channel=4, note=93, velocity=100, time=0),
#     Message('note_off', channel=4, note=81, velocity=0, time=60),
#     Message('note_off', channel=4, note=93, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_on', channel=4, note=91, velocity=100, time=0),
#     Message('note_off', channel=4, note=79, velocity=0, time=60),
#     Message('note_off', channel=4, note=91, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=30),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=30),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=60),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=75, velocity=100, time=0),
#     Message('note_on', channel=4, note=87, velocity=100, time=0),
#     Message('note_off', channel=4, note=75, velocity=0, time=60),
#     Message('note_off', channel=4, note=87, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=30),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=30),
#     Message('note_on', channel=4, note=93, velocity=100, time=0),
#     Message('note_off', channel=4, note=81, velocity=0, time=60),
#     Message('note_off', channel=4, note=93, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=60),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=57, velocity=100, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_off', channel=4, note=57, velocity=0, time=60),
#     Message('note_off', channel=4, note=69, velocity=0, time=0),
#     Message('note_on', channel=4, note=59, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_off', channel=4, note=59, velocity=0, time=60),
#     Message('note_off', channel=4, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=60, velocity=100, time=0),
#     Message('note_on', channel=4, note=72, velocity=100, time=0),
#     Message('note_off', channel=4, note=60, velocity=0, time=60),
#     Message('note_off', channel=4, note=72, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=60),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=63, velocity=100, time=0),
#     Message('note_on', channel=4, note=75, velocity=100, time=0),
#     Message('note_off', channel=4, note=63, velocity=0, time=60),
#     Message('note_off', channel=4, note=75, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=65, velocity=100, time=0),
#     Message('note_on', channel=4, note=77, velocity=100, time=0),
#     Message('note_off', channel=4, note=65, velocity=0, time=60),
#     Message('note_off', channel=4, note=77, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=30),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=30),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=30),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=30),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=64, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_off', channel=4, note=64, velocity=0, time=60),
#     Message('note_off', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=61, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_off', channel=4, note=61, velocity=0, time=60),
#     Message('note_off', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=30),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=30),
#     Message('note_on', channel=4, note=93, velocity=100, time=0),
#     Message('note_off', channel=4, note=81, velocity=0, time=60),
#     Message('note_off', channel=4, note=93, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_on', channel=4, note=91, velocity=100, time=0),
#     Message('note_off', channel=4, note=79, velocity=0, time=60),
#     Message('note_off', channel=4, note=91, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_off', channel=4, note=67, velocity=0, time=60),
#     Message('note_off', channel=4, note=79, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=62, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_off', channel=4, note=62, velocity=0, time=60),
#     Message('note_off', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=66, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_off', channel=4, note=66, velocity=0, time=60),
#     Message('note_off', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_off', channel=4, note=78, velocity=0, time=60),
#     Message('note_off', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_off', channel=4, note=76, velocity=0, time=60),
#     Message('note_off', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_off', channel=4, note=74, velocity=0, time=60),
#     Message('note_off', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_off', channel=4, note=73, velocity=0, time=60),
#     Message('note_off', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_off', channel=4, note=68, velocity=0, time=60),
#     Message('note_off', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_off', channel=4, note=71, velocity=0, time=60),
#     Message('note_off', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_off', channel=4, note=69, velocity=0, time=60),
#     Message('note_off', channel=4, note=81, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
# ...
#     Message('control_change', channel=9, control=11, value=127, time=60),
#     Message('control_change', channel=9, control=76, value=0, time=60),
#     Message('control_change', channel=9, control=77, value=0, time=60),
#     Message('control_change', channel=9, control=78, value=0, time=60),
#     Message('control_change', channel=9, control=74, value=64, time=60),
#     Message('control_change', channel=9, control=71, value=64, time=60),
#     Message('control_change', channel=9, control=73, value=64, time=60),
#     Message('control_change', channel=9, control=75, value=0, time=60),
#     Message('control_change', channel=9, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=2460)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=10, control=123, value=0, time=0),
#     Message('control_change', channel=10, control=121, value=0, time=40),
#     Message('control_change', channel=10, control=7, value=100, time=440),
#     Message('control_change', channel=10, control=10, value=64, time=60),
#     Message('control_change', channel=10, control=0, value=0, time=60),
#     Message('control_change', channel=10, control=32, value=3, time=0),
#     Message('program_change', channel=10, program=0, time=0),
#     Message('control_change', channel=10, control=91, value=40, time=60),
#     Message('control_change', channel=10, control=93, value=0, time=60),
#     Message('control_change', channel=10, control=94, value=0, time=60),
#     Message('pitchwheel', channel=10, pitch=0, time=60),
#     Message('control_change', channel=10, control=11, value=127, time=60),
#     Message('control_change', channel=10, control=76, value=0, time=60),
#     Message('control_change', channel=10, control=77, value=0, time=60),
#     Message('control_change', channel=10, control=78, value=0, time=60),
#     Message('control_change', channel=10, control=74, value=64, time=60),
#     Message('control_change', channel=10, control=71, value=64, time=60),
#     Message('control_change', channel=10, control=73, value=64, time=60),
#     Message('control_change', channel=10, control=75, value=0, time=60),
#     Message('control_change', channel=10, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=540)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=11, control=123, value=0, time=0),
#     Message('control_change', channel=11, control=121, value=0, time=40),
#     Message('control_change', channel=11, control=7, value=100, time=440),
#     Message('control_change', channel=11, control=10, value=64, time=60),
#     Message('control_change', channel=11, control=0, value=0, time=60),
#     Message('control_change', channel=11, control=32, value=3, time=0),
#     Message('program_change', channel=11, program=0, time=0),
#     Message('control_change', channel=11, control=91, value=40, time=60),
#     Message('control_change', channel=11, control=93, value=0, time=60),
#     Message('control_change', channel=11, control=94, value=0, time=60),
#     Message('pitchwheel', channel=11, pitch=0, time=60),
#     Message('control_change', channel=11, control=11, value=127, time=60),
#     Message('control_change', channel=11, control=76, value=0, time=60),
#     Message('control_change', channel=11, control=77, value=0, time=60),
#     Message('control_change', channel=11, control=78, value=0, time=60),
#     Message('control_change', channel=11, control=74, value=64, time=60),
#     Message('control_change', channel=11, control=71, value=64, time=60),
#     Message('control_change', channel=11, control=73, value=64, time=60),
#     Message('control_change', channel=11, control=75, value=0, time=60),
#     Message('control_change', channel=11, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=540)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=12, control=123, value=0, time=0),
#     Message('control_change', channel=12, control=121, value=0, time=40),
#     Message('control_change', channel=12, control=7, value=100, time=440),
#     Message('control_change', channel=12, control=10, value=64, time=60),
#     Message('control_change', channel=12, control=0, value=0, time=60),
#     Message('control_change', channel=12, control=32, value=3, time=0),
#     Message('program_change', channel=12, program=0, time=0),
#     Message('control_change', channel=12, control=91, value=40, time=60),
#     Message('control_change', channel=12, control=93, value=0, time=60),
#     Message('control_change', channel=12, control=94, value=0, time=60),
#     Message('pitchwheel', channel=12, pitch=0, time=60),
#     Message('control_change', channel=12, control=11, value=127, time=60),
#     Message('control_change', channel=12, control=76, value=0, time=60),
#     Message('control_change', channel=12, control=77, value=0, time=60),
#     Message('control_change', channel=12, control=78, value=0, time=60),
#     Message('control_change', channel=12, control=74, value=64, time=60),
#     Message('control_change', channel=12, control=71, value=64, time=60),
#     Message('control_change', channel=12, control=73, value=64, time=60),
#     Message('control_change', channel=12, control=75, value=0, time=60),
#     Message('control_change', channel=12, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=540)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=13, control=123, value=0, time=0),
#     Message('control_change', channel=13, control=121, value=0, time=40),
#     Message('control_change', channel=13, control=7, value=100, time=440),
#     Message('control_change', channel=13, control=10, value=64, time=60),
#     Message('control_change', channel=13, control=0, value=0, time=60),
#     Message('control_change', channel=13, control=32, value=3, time=0),
#     Message('program_change', channel=13, program=0, time=0),
#     Message('control_change', channel=13, control=91, value=40, time=60),
#     Message('control_change', channel=13, control=93, value=0, time=60),
#     Message('control_change', channel=13, control=94, value=0, time=60),
#     Message('pitchwheel', channel=13, pitch=0, time=60),
#     Message('control_change', channel=13, control=11, value=127, time=60),
#     Message('control_change', channel=13, control=76, value=0, time=60),
#     Message('control_change', channel=13, control=77, value=0, time=60),
#     Message('control_change', channel=13, control=78, value=0, time=60),
#     Message('control_change', channel=13, control=74, value=64, time=60),
#     Message('control_change', channel=13, control=71, value=64, time=60),
#     Message('control_change', channel=13, control=73, value=64, time=60),
#     Message('control_change', channel=13, control=75, value=0, time=60),
#     Message('control_change', channel=13, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=540)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=14, control=123, value=0, time=0),
#     Message('control_change', channel=14, control=121, value=0, time=40),
#     Message('control_change', channel=14, control=7, value=100, time=440),
#     Message('control_change', channel=14, control=10, value=64, time=60),
#     Message('control_change', channel=14, control=0, value=0, time=60),
#     Message('control_change', channel=14, control=32, value=3, time=0),
#     Message('program_change', channel=14, program=0, time=0),
#     Message('control_change', channel=14, control=91, value=40, time=60),
#     Message('control_change', channel=14, control=93, value=0, time=60),
#     Message('control_change', channel=14, control=94, value=0, time=60),
#     Message('pitchwheel', channel=14, pitch=0, time=60),
#     Message('control_change', channel=14, control=11, value=127, time=60),
#     Message('control_change', channel=14, control=76, value=0, time=60),
#     Message('control_change', channel=14, control=77, value=0, time=60),
#     Message('control_change', channel=14, control=78, value=0, time=60),
#     Message('control_change', channel=14, control=74, value=64, time=60),
#     Message('control_change', channel=14, control=71, value=64, time=60),
#     Message('control_change', channel=14, control=73, value=64, time=60),
#     Message('control_change', channel=14, control=75, value=0, time=60),
#     Message('control_change', channel=14, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=2460)]),
#   MidiTrack([
#     MetaMessage('track_name', name='', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=15, control=123, value=0, time=0),
#     Message('control_change', channel=15, control=121, value=0, time=40),
#     Message('control_change', channel=15, control=7, value=100, time=440),
#     Message('control_change', channel=15, control=10, value=64, time=60),
#     Message('control_change', channel=15, control=0, value=0, time=60),
#     Message('control_change', channel=15, control=32, value=3, time=0),
#     Message('program_change', channel=15, program=0, time=0),
#     Message('control_change', channel=15, control=91, value=40, time=60),
#     Message('control_change', channel=15, control=93, value=0, time=60),
#     Message('control_change', channel=15, control=94, value=0, time=60),
#     Message('pitchwheel', channel=15, pitch=0, time=60),
#     Message('control_change', channel=15, control=11, value=127, time=60),
#     Message('control_change', channel=15, control=76, value=0, time=60),
#     Message('control_change', channel=15, control=77, value=0, time=60),
#     Message('control_change', channel=15, control=78, value=0, time=60),
#     Message('control_change', channel=15, control=74, value=64, time=60),
#     Message('control_change', channel=15, control=71, value=64, time=60),
#     Message('control_change', channel=15, control=73, value=64, time=60),
#     Message('control_change', channel=15, control=75, value=0, time=60),
#     Message('control_change', channel=15, control=72, value=64, time=60),
#     MetaMessage('end_of_track', time=2460)])
# ])
# CONTROL ALL NOTES OFF MESSAGE!
# <ipython-input-7-0f2eb8871836>:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   time_series, sr = librosa.core.load(audio_file, sr=22050*4)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     220         # Load the target number of frames, and transpose to match librosa form
# --> 221         y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     222
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in read(self, frames, dtype, always_2d, fill_value, out)
#     894                 frames = len(out)
# --> 895         frames = self._array_io('read', out, frames)
#     896         if len(out) > frames:
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _array_io(self, action, array, frames)
#    1343         cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1344         return self._cdata_io(action, cdata, ctype, frames)
#    1345
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _cdata_io(self, action, data, ctype, frames)
#    1353         frames = func(self._file, data, frames)
# -> 1354         _error_check(self._errorcode)
#    1355         if self.seekable():
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _error_check(err, prefix)
#    1406     if err != 0:
# -> 1407         raise LibsndfileError(err, prefix=prefix)
#    1408
#
# LibsndfileError: System error.
#
# During handling of the above exception, another exception occurred:
#
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         try:
# --> 175             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     176
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     209
# --> 210     with context as sf_desc:
#     211         sr_native = sf_desc.samplerate
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in __exit__(self, *args)
#     722     def __exit__(self, *args):
# --> 723         self.close()
#     724
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in close(self)
#    1187             self._file = None
# -> 1188             _error_check(err)
#    1189
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _error_check(err, prefix)
#    1406     if err != 0:
# -> 1407         raise LibsndfileError(err, prefix=prefix)
#    1408
#
# LibsndfileError: No error defined for this error number. This is a bug in libsndfile.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-906ae8e81b07> in <cell line: 2>()
#       1 directory_str = "./audio_and_midi"
# ----> 2 preprocess_audio_and_midi(directory_str)
#       3 start_time = time.time()
#       4 print("--- %s seconds ---" % (time.time() - start_time))
#
# <ipython-input-16-8d107bd546f1> in preprocess_audio_and_midi(directory_str)
#       5     midi_segments_count = 0
#       6     for audio_file in audio_files:
# ----> 7         audio_decoded = load_audio(audio_file)
#       8         time_series, sr = audio_decoded
#       9         audio_start_times, audio_segment_length, midi_segment_length = audio_timestamps(
#
# <ipython-input-7-0f2eb8871836> in load_audio(audio_file)
#       9
#      10 def load_audio(audio_file):
# ---> 11     time_series, sr = librosa.core.load(audio_file, sr=22050*4)
#      12     time_series_and_sr = AudioDecoded(time_series, sr)
#      13     return time_series_and_sr
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     181                     "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     182                 )
# --> 183                 y, sr_native = __audioread_load(path, offset, duration, dtype)
#     184             else:
#     185                 raise exc
#
# <decorator-gen-119> in __audioread_load(path, offset, duration, dtype)
#
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py in __wrapper(func, *args, **kwargs)
#      57             stacklevel=3,  # Would be 2, but the decorator adds a level
#      58         )
# ---> 59         return func(*args, **kwargs)
#      60
#      61     return decorator(__wrapper)
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     237     else:
#     238         # If the input was not an audioread object, try to open it
# --> 239         reader = audioread.audio_open(path)
#     240
#     241     with reader as input_file:
#
# /usr/local/lib/python3.10/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     125     for BackendClass in backends:
#     126         try:
# --> 127             return BackendClass(path)
#     128         except DecodeError:
#     129             pass
#
# /usr/local/lib/python3.10/dist-packages/audioread/rawread.py in __init__(self, filename)
#      57     """
#      58     def __init__(self, filename):
# ---> 59         self._fh = open(filename, 'rb')
#      60
#      61         try:
#
# OSError: [Errno 107] Transport endpoint is not connected: '/content/gdrive/MyDrive/kaggle/audio_and_midi/audio/1733.wav'
